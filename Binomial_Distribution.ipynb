# %% [markdown]
# <a href="https://colab.research.google.com/github/janubro0125/Varsha-S-S-Data-Science/blob/main/Binomial_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from scipy.stats  import binom
import numpy as np
n=12
p=0.6
k=10
prob=binom.pmf(k,n,p)#shows highest possibilty is 0.06  which means 60% chance for sucess
print(prob)
# Out:
# 0.06385228185600002

# %%
x = np.arange(0, n + 1)
pmf_values = binom.pmf(x, n, p)
plt.bar(x, pmf_values, color="violet", edgecolor="black", label="Binomial PMF")

# highlight k = 10
plt.bar(k, prob, color="red", edgecolor="black", label=f"k = {k}")

plt.xlabel("Number of successes")
plt.ylabel("Probability")
plt.title(f"Binomial distribution")
plt.legend()
plt.grid(axis="y", alpha=0.3)
plt.show()
