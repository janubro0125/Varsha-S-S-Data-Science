# %% [markdown]
# <a href="https://colab.research.google.com/github/janubro0125/Varsha-S-S-Data-Science/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
detail={"Name":["Varsha","Darsini","Ramesh","Tharsan"],"Domain":["Data Analyst","Data scientist","Data Analyst","Business Management"]}
detail
# Out:
# {'Name': ['Varsha', 'Darsini', 'Ramesh', 'Tharsan'],
#  'Domain': ['Data Analyst',
#   'Data scientist',
#   'Data Analyst',
#   'Business Management']}

# %%
data=pd.DataFrame(detail)
data
# Out:
#       Name               Domain
# 0   Varsha         Data Analyst
# 1  Darsini       Data scientist
# 2   Ramesh         Data Analyst
# 3  Tharsan  Business Management

# %%
dd=data.to_csv("details.csv")
dd

# %%
s=pd.read_csv("details.csv")
s
# Out:
#    Unnamed: 0     Name               Domain
# 0           0   Varsha         Data Analyst
# 1           1  Darsini       Data scientist
# 2           2   Ramesh         Data Analyst
# 3           3  Tharsan  Business Management

# %%
Name=s["Name"]
Name
# Out:
# 0     Varsha
# 1    Darsini
# 2     Ramesh
# 3    Tharsan
# Name: Name, dtype: object

# %%
Name=s.loc[0:1,"Name"]
Name
# Out:
# 0     Varsha
# 1    Darsini
# Name: Name, dtype: object

# %%
Skincare=pd.read_csv("Skincare_Brands_Sales_Dataset.csv")
Skincare
# Out:
#       Row ID        Order ID  Order Date   Ship Date          Ship Mode  \
# 0          1  SK-2020-000001  07/28/2020  08/03/2020   Express Delivery
# 1          2  SK-2023-000002  08/23/2023  08/29/2023   Express Delivery
# 2          3  SK-2022-000003  02/17/2022  02/18/2022  Standard Delivery
# 3          4  SK-2023-000004  03/28/2023  03/30/2023           Same Day
# 4          5  SK-2021-000005  12/28/2021  12/30/2021           Same Day
# ...      ...             ...         ...         ...                ...
# 9989    9990  SK-2023-009990  04/28/2023  05/05/2023           Same Day
# 9990    9991  SK-2022-009991  11/24/2022  11/29/2022    Click & Collect
# 9991    9992  SK-2020-009992  07/11/2020  07/15/2020   Express Delivery
# 9992    9993  SK-2021-009993  06/02/2021  06/08/2021   Express Delivery
# 9993    9994  SK-2021-009994  04/11/2021  04/18/2021   Express Delivery
#
#      Customer ID    Customer Name   Segment        Country       City  ...  \
# ...

# %%
print(Skincare.head())
# Out:
#    Row ID        Order ID  Order Date   Ship Date          Ship Mode  \
# 0       1  SK-2020-000001  07/28/2020  08/03/2020   Express Delivery
# 1       2  SK-2023-000002  08/23/2023  08/29/2023   Express Delivery
# 2       3  SK-2022-000003  02/17/2022  02/18/2022  Standard Delivery
# 3       4  SK-2023-000004  03/28/2023  03/30/2023           Same Day
# 4       5  SK-2021-000005  12/28/2021  12/30/2021           Same Day
#
#   Customer ID    Customer Name   Segment        Country       City  ...  \
# 0    SC-13905       Sofia Chen    Retail  United States   New York  ...
# 1    SC-30926       Aria Patel  Pharmacy  United States    Houston  ...
# 2    SC-70217       Sofia Chen    Retail  United States  Charlotte  ...
# 3    SC-20458  Evelyn Anderson  Pharmacy  United States     Boston  ...
# 4    SC-42087       Camila Lee    Retail  United States     Boston  ...
#
#   Region       Product ID             Category Sub-Category  \
# ...

# %%
print(Skincare.tail())
# Out:
#       Row ID        Order ID  Order Date   Ship Date         Ship Mode  \
# 9989    9990  SK-2023-009990  04/28/2023  05/05/2023          Same Day
# 9990    9991  SK-2022-009991  11/24/2022  11/29/2022   Click & Collect
# 9991    9992  SK-2020-009992  07/11/2020  07/15/2020  Express Delivery
# 9992    9993  SK-2021-009993  06/02/2021  06/08/2021  Express Delivery
# 9993    9994  SK-2021-009994  04/11/2021  04/18/2021  Express Delivery
#
#      Customer ID Customer Name Segment        Country      City  ... Region  \
# 9989    SC-29099    Camila Lee  Retail  United States   Atlanta  ...  South
# 9990    SC-68853  Amelia Moore  Retail  United States   Chicago  ...  North
# 9991    SC-68451   Ella Martin  Online  United States     Miami  ...  South
# 9992    SC-17759   Mila Harris  Retail  United States  New York  ...  North
# 9993    SC-53861    Sofia Chen  Retail  United States   Atlanta  ...  South
#
#            Product ID             Category      Sub-Category  \
# ...

# %%
print(Skincare.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
print(Skincare.describe())
# Out:
#             Row ID   Postal Code        Sales     Quantity     Discount  \
# count  9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   4997.500000  48900.109466   437.827597     5.503102     0.083215
# std    2885.163629  33206.049108   390.018594     2.871552     0.074347
# min       1.000000   2101.000000     5.120000     1.000000     0.000000
# 25%    2499.250000  28201.000000   140.547500     3.000000     0.000000
# 50%    4997.500000  33101.000000   314.795000     5.500000     0.100000
# 75%    7495.750000  90001.000000   620.170000     8.000000     0.150000
# max    9994.000000  98101.000000  2180.700000    10.000000     0.200000
#
#             Profit
# count  9994.000000
# mean    138.539785
# std     137.914219
# min       0.833800
# 25%      39.665925
# 50%      91.596450
# 75%     192.297400
# max     961.596500
