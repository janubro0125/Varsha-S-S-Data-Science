# %% [markdown]
# <a href="https://colab.research.google.com/github/janubro0125/Varsha-S-S-Data-Science/blob/main/Poisson_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#if the call center received 10 calls per min
#means,how much of minutes need for receiving 15 calls
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson as p
lam=10
k=15
pos=p.pmf(k,lam)
print("probability of getting 15 call in a minute:",pos)
x=np.arange(0,21)
fit=p.pmf(x,lam)
plt.bar(x,fit,color="purple")
plt.title("poisson distribution")
plt.xlabel("no of calls in per minute")
plt.ylabel("probability")#chances
plt.show()
# Out:
# probability of getting 15 call in a minute: 0.034718069630684245
