# %% [markdown]
# <a href="https://colab.research.google.com/github/janubro0125/Varsha-S-S-Data-Science/blob/main/Q_QPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

df = pd.read_csv("Iris.csv")

stats.probplot(
    df["SepalLengthCm"],
    dist="norm",
    plot=plt
)

plt.title("normal  distribution QQ Plot - Iris Sepal Length")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

df = pd.read_csv("Iris.csv")

stats.probplot(
    df["PetalLengthCm"],
    dist="norm",
    plot=plt
)

plt.title("normal  distribution QQ Plot - Iris Petal Length")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

df = pd.read_csv("Mall_Customers.csv")

stats.probplot(
    df["Age"],
    dist="norm",
    plot=plt
)

plt.title("QQ Plot - Customer Age")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

df = pd.read_csv("Housing.csv")

stats.probplot(
    df["price"],
    dist="norm",
    plot=plt
)

plt.title("Exponential distribution QQ Plot - House Sale Price")
plt.show()
