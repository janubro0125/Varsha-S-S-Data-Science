# %% [markdown]
# <a href="https://colab.research.google.com/github/janubro0125/Varsha-S-S-Data-Science/blob/main/Z_score_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.stats import zscore
# Data values
data = [10, 20, 30, 40, 50]
# Automatic Z-score calculation
result = zscore(data)
print("Data:", data)
print("Z-scores:", result)
# Out:
# Data: [10, 20, 30, 40, 50]
# Z-scores: [-1.41421356 -0.70710678  0.          0.70710678  1.41421356]
